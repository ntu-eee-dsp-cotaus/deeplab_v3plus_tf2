# %%
import tensorflow as tf
import tensorflow.keras as tfk
import tensorflow.keras.layers as tfkl

# %%
reader = tf.train.load_checkpoint('/home/karn/deeplab_v3plus_tf2/deeplab_mnv3_large_cityscapes_trainfine/model.ckpt')

# %%
sorted(reader.get_variable_to_shape_map())
# Out:
# ['MobilenetV3/Conv/BatchNorm/beta',
#  'MobilenetV3/Conv/BatchNorm/beta/Momentum',
#  'MobilenetV3/Conv/BatchNorm/gamma',
#  'MobilenetV3/Conv/BatchNorm/gamma/Momentum',
#  'MobilenetV3/Conv/BatchNorm/moving_mean',
#  'MobilenetV3/Conv/BatchNorm/moving_variance',
#  'MobilenetV3/Conv/weights',
#  'MobilenetV3/Conv/weights/Momentum',
#  'MobilenetV3/Conv_1/BatchNorm/beta',
#  'MobilenetV3/Conv_1/BatchNorm/beta/Momentum',
#  'MobilenetV3/Conv_1/BatchNorm/gamma',
#  'MobilenetV3/Conv_1/BatchNorm/gamma/Momentum',
#  'MobilenetV3/Conv_1/BatchNorm/moving_mean',
#  'MobilenetV3/Conv_1/BatchNorm/moving_variance',
#  'MobilenetV3/Conv_1/weights',
#  'MobilenetV3/Conv_1/weights/Momentum',
#  'MobilenetV3/expanded_conv/depthwise/BatchNorm/beta',
#  'MobilenetV3/expanded_conv/depthwise/BatchNorm/beta/Momentum',
#  'MobilenetV3/expanded_conv/depthwise/BatchNorm/gamma',
#  'MobilenetV3/expanded_conv/depthwise/BatchNorm/gamma/Momentum',
# ...

# %%
mn3 = tf.keras.applications.MobileNetV3Large()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# ...
# 22667264/22661472 [==============================] - 1s 0us/step

# %%
for l in mn3.layers:
    if l.weights:
        for w in l.weights:
            print(l.name, w.name)
# Out:
# Conv Conv/kernel:0
# Conv/BatchNorm Conv/BatchNorm/gamma:0
# Conv/BatchNorm Conv/BatchNorm/beta:0
# Conv/BatchNorm Conv/BatchNorm/moving_mean:0
# Conv/BatchNorm Conv/BatchNorm/moving_variance:0
# expanded_conv/depthwise expanded_conv/depthwise/depthwise_kernel:0
# expanded_conv/depthwise/BatchNorm expanded_conv/depthwise/BatchNorm/gamma:0
# expanded_conv/depthwise/BatchNorm expanded_conv/depthwise/BatchNorm/beta:0
# expanded_conv/depthwise/BatchNorm expanded_conv/depthwise/BatchNorm/moving_mean:0
# expanded_conv/depthwise/BatchNorm expanded_conv/depthwise/BatchNorm/moving_variance:0
# expanded_conv/project expanded_conv/project/kernel:0
# expanded_conv/project/BatchNorm expanded_conv/project/BatchNorm/gamma:0
# expanded_conv/project/BatchNorm expanded_conv/project/BatchNorm/beta:0
# expanded_conv/project/BatchNorm expanded_conv/project/BatchNorm/moving_mean:0
# expanded_conv/project/BatchNorm expanded_conv/project/BatchNorm/moving_variance:0
# ...

# %%
mn3.summary()
# Out:
# Model: "MobilenetV3large"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv (Conv2D)                   (None, None, None, 1 432         rescaling[0][0]
# __________________________________________________________________________________________________
# Conv/BatchNorm (BatchNormalizat (None, None, None, 1 64          Conv[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, None, None, 1 0           Conv/BatchNorm[0][0]
# ...
